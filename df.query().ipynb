# %%
import pandas as pd

# %%
df = pd.read_csv("data_from_trip_practice_only.csv")
df.head()
# Out:
#   countrynameen country_grouped  masterhotelid  \
# 0      Malaysia        Malaysia         699489
# 1      Malaysia        Malaysia         698563
# 2      Malaysia        Malaysia         698608
# 3      Malaysia        Malaysia         695037
# 4      Malaysia        Malaysia        1465325
#
#                                      masterhotelname  hotel_category  \
# 0     槟城火烈鸟海滩酒店(Flamingo Hotel by The Beach, Penang)             NaN
# 1  吉隆坡棉兰东姑普雷斯科特酒店(Prescott Hotel Kuala Lumpur Med...             NaN
# 2              吉隆坡皇家朱兰酒店(Royale Chulan Kuala Lumpur)             NaN
# 3                        KSL度假酒店(KSL Hotel & Resort)             NaN
# 4                 马六甲瑞园酒店(Swiss-Garden Hotel Melaka)             NaN
#
#    wkn_period  this_wk_in_cpn  this_wk_order  this_wk_uv  \
# 0  11/15/2021               0            188        2218
# 1  11/15/2021               0            147         707
# 2  11/15/2021               0            141        1770
# ...

# %% [markdown]
# ## Normal use

# %%
df.query('this_wk_uv > 2000')  # same as df[ df["this_wk_uv"]>2000 ]
# Out:
#       countrynameen country_grouped  masterhotelid  \
# 0          Malaysia        Malaysia         699489
# 2135       Malaysia        Malaysia         699489
# 2136       Malaysia        Malaysia        1465325
# 2167       Malaysia        Malaysia         992455
# 3847       Malaysia        Malaysia         699489
# 3850       Malaysia        Malaysia        1465325
# 3855       Malaysia        Malaysia         992455
# 3857       Malaysia        Malaysia         993013
# 3863       Malaysia        Malaysia         994074
# 5719       Malaysia        Malaysia         699489
# 5722       Malaysia        Malaysia        1465325
# 7807    South Korea     South Korea       12093236
# 7808    South Korea     South Korea       25673737
# 7810    South Korea     South Korea       15677672
# 10189   South Korea     South Korea       12093236
# 11988   South Korea     South Korea       12093236
# 14351   South Korea     South Korea       12093236
# ...

# %%
df.query('this_wk_uv > 2000 & this_wk_order > 200')
# Out:
#       countrynameen country_grouped  masterhotelid  \
# 2135       Malaysia        Malaysia         699489
# 5719       Malaysia        Malaysia         699489
# 7807    South Korea     South Korea       12093236
# 7808    South Korea     South Korea       25673737
# 7810    South Korea     South Korea       15677672
# 10189   South Korea     South Korea       12093236
# 11988   South Korea     South Korea       12093236
# 14351   South Korea     South Korea       12093236
# 14352   South Korea     South Korea       25673737
# 14353   South Korea     South Korea        7090954
# 14354   South Korea     South Korea       15677672
#
#                                          masterhotelname  hotel_category  \
# 2135      槟城火烈鸟海滩酒店(Flamingo Hotel by The Beach, Penang)             NaN
# 5719      槟城火烈鸟海滩酒店(Flamingo Hotel by The Beach, Penang)             NaN
# 7807   济州神话世界度假酒店 – 蓝鼎(Landing Jeju Shinhwa World Hot...             NaN
# ...

# %%
df.query('this_wk_uv > 2000 | this_wk_order > 200')
# Out:
#       countrynameen country_grouped  masterhotelid  \
# 0          Malaysia        Malaysia         699489
# 2135       Malaysia        Malaysia         699489
# 2136       Malaysia        Malaysia        1465325
# 2167       Malaysia        Malaysia         992455
# 3847       Malaysia        Malaysia         699489
# 3850       Malaysia        Malaysia        1465325
# 3855       Malaysia        Malaysia         992455
# 3857       Malaysia        Malaysia         993013
# 3863       Malaysia        Malaysia         994074
# 5719       Malaysia        Malaysia         699489
# 5722       Malaysia        Malaysia        1465325
# 7807    South Korea     South Korea       12093236
# 7808    South Korea     South Korea       25673737
# 7809    South Korea     South Korea        4548893
# 7810    South Korea     South Korea       15677672
# 10189   South Korea     South Korea       12093236
# 11988   South Korea     South Korea       12093236
# ...
